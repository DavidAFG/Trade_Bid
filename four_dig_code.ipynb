# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Inserting libraries to work
import pandas as pd
import numpy as np
from pathlib import Path
import os
import re
import time
import comtradeapicall
import glob
import traceback
import pyarrow
import fastparquet
import matplotlib.pyplot as plt
# Out:
# /Users/david/Documents/BID/Trade/Trade_Bid/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # Comtrade API CALL at 4 digits

# %%
# insert relevant two digit codes database
two_dig = pd.read_csv("relevant_two_digit_codes.csv")

# insert excel database to get the 4 digit codes
hscodes = pd.read_excel("HSCodeandDescription.xlsx")
hscodes["Code"] = hscodes["Code"].astype(str).str.strip()

#  Ensure two_dig is a list of 2-digit strings like ["01","27","84",...]
if isinstance(two_dig, (pd.DataFrame, pd.Series)):
    # If it's a DataFrame with a column named "item2" or "Code", pick the right one:
    col = "item2" if "item2" in getattr(two_dig, "columns", []) else two_dig.name
    two_dig_list = two_dig[col].astype(str).str.zfill(2).tolist() if isinstance(two_dig, pd.DataFrame) else two_dig.astype(str).str.zfill(2).tolist()
else:
    two_dig_list = [str(x).zfill(2) for x in two_dig]

two_dig_set = set(two_dig_list)
print(two_dig_set)

# Filter HS codes to get relevant 4-digit codes
hs_level4_relevant = hscodes[
    (hscodes["Level"] == 4) &
    (hscodes["Code"].str[:2].isin(two_dig_set))
].copy()

hs_level4_relevant.head()

hs_four_code = hs_level4_relevant["Code"].tolist()
hs_four_code
# Out:
# {'50', '90', '20', '30', '87', '70', '27', '10', '81', '29', '85', '25', '40', '95', '84', '91', '51', '14', '80', '72', '39'}
# ['1001',
#  '1002',
#  '1003',
#  '1004',
#  '1005',
#  '1006',
#  '1007',
#  '1008',
#  '1401',
#  '1404',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2501',
#  '2502',
#  '2503',
#  '2504',
#  '2505',
#  '2506',
#  '2507',
#  '2508',
#  '2509',
#  '2510',
#  '2511',
#  '2512',
#  '2513',
#  '2514',
#  '2515',
#  '2516',
#  '2517',
#  '2518',
#  '2519',
#  '2520',
#  '2521',
#  '2522',
#  '2523',
#  '2524',
#  '2525',
#  '2526',
#  '2528',
#  '2529',
#  '2530',
#  '2701',
#  '2702',
#  '2703',
#  '2704',
#  '2705',
#  '2706',
#  '2707',
#  '2708',
#  '2709',
#  '2710',
#  '2711',
#  '2712',
#  '2713',
#  '2714',
#  '2715',
#  '2716',
#  '2901',
#  '2902',
#  '2903',
#  '2904',
#  '2905',
#  '2906',
#  '2907',
#  '2908',
#  '2909',
#  '2910',
#  '2911',
#  '2912',
#  '2913',
#  '2914',
#  '2915',
# ...

# %%
subscription_key = "3052290edec74a228fdf50950851da90"

def get_comtrade_hs4_official(
    subscription_key: str,
    year: int,
    reporter_code: str,
    hs_four_code: list[str],            # <-- your ready-made HS4 list
    partner_code: str | None = None,    # None = all partners
    flow_code: str = "X",
    cl_code: str = "HS",
    breakdown_mode: str = "classic",
    max_records: int = 90000,
    chunk_size: int = 50
):
    out = []

    for i in range(0, len(hs_four_code), chunk_size):
        chunk = hs_four_code[i:i + chunk_size]
        cmd_code = ",".join(chunk)

        df_chunk = comtradeapicall.getFinalData(
            subscription_key,
            typeCode="C",
            freqCode="A",
            clCode=cl_code,
            period=str(year),
            reporterCode=str(reporter_code),
            cmdCode=cmd_code,                 # <-- ONLY these HS4 codes
            flowCode=flow_code,
            partnerCode=partner_code,
            partner2Code=None,
            customsCode=None,
            motCode=None,
            maxRecords=max_records,
            format_output="JSON",
            aggregateBy=None,
            breakdownMode=breakdown_mode,
            countOnly=None,
            includeDesc=True
        )

        if df_chunk is not None and len(df_chunk) > 0:
            out.append(df_chunk)

    return pd.concat(out, ignore_index=True) if out else pd.DataFrame()

# %%
# --- inputs ---
#years = [2003, 2009, 2017, 2021]
years = [2021]
# due to quotas, given the account, the free account allows to get all the data for one year per day
# year 2003 done
# year 2009 
# year 2017
# year 2021 


reporter_codes = ["32","76","222","251","276",
                  "340","380","392","484","554",
                  "566","608","643","682","724",
                  "740","792","842","716","156","124","826",
                  "702"]
flow_codes = ["X", "M"]
partner_code = None
out_dir = "comtrade_data_hs4"
sleep_s = 5.0

os.makedirs(out_dir, exist_ok=True)

keep_cols = ["flowCode", "reporterCode", "reporterISO", "partnerCode", "partnerISO",
             "cmdCode", "cmdDesc", "qtyUnitAbbr", "qty", "fobvalue"]

def safe_filename(s: str) -> str:
    s = str(s).strip()
    return re.sub(r"[^\w\-\.]+", "_", s)

# IMPORTANT: you already have this list prepared:
# hs_four_code = hs_level4_relevant["Code"].tolist()

for year in years:
    for reporter_code in reporter_codes:
        for flow_code in flow_codes:
            try:
                df_hs4 = get_comtrade_hs4_official(
                    subscription_key=subscription_key,
                    year=year,
                    reporter_code=str(reporter_code),
                    hs_four_code=hs_four_code,     # <-- HS4 framework
                    partner_code=partner_code,
                    flow_code=str(flow_code),
                    chunk_size=50                  # adjust if needed
                )

                if df_hs4 is None or df_hs4.empty:
                    print(f"⚠ Empty result: reporter={reporter_code}, flow={flow_code}, year={year}")
                    continue

                cols_present = [c for c in keep_cols if c in df_hs4.columns]
                df_hs4_boni = df_hs4[cols_present].copy()

                rep_iso = df_hs4_boni["reporterISO"].iloc[0] if "reporterISO" in df_hs4_boni.columns else reporter_code
                flw = df_hs4_boni["flowCode"].iloc[0] if "flowCode" in df_hs4_boni.columns else flow_code

                fname = f"{safe_filename(rep_iso)}_{safe_filename(flw)}_{year}_HS4.csv"
                fpath = os.path.join(out_dir, fname)

                df_hs4_boni.to_csv(fpath, index=False)
                print(f"✓ Saved {fpath}  ({df_hs4_boni.shape[0]} rows, {df_hs4_boni.shape[1]} cols)")

                time.sleep(sleep_s)

            except Exception as e:
                print(f"✗ Failed: reporter={reporter_code}, flow={flow_code}, year={year} → {e}")
# Out:
# ✓ Saved comtrade_data_hs4/ARG_X_2021_HS4.csv  (1364 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/ARG_M_2021_HS4.csv  (11146 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/BRA_X_2021_HS4.csv  (21830 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/BRA_M_2021_HS4.csv  (14616 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/SLV_X_2021_HS4.csv  (2518 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/SLV_M_2021_HS4.csv  (9368 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/FRA_X_2021_HS4.csv  (43451 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/FRA_M_2021_HS4.csv  (26928 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/DEU_X_2021_HS4.csv  (47290 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/DEU_M_2021_HS4.csv  (23737 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/HND_X_2021_HS4.csv  (2108 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/HND_M_2021_HS4.csv  (8774 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/ITA_X_2021_HS4.csv  (41927 rows, 10 cols)
# ✓ Saved comtrade_data_hs4/ITA_M_2021_HS4.csv  (20643 rows, 10 cols)
# ...

# %% [markdown]
# ## Joining Comtrade at 4 Digits for all countries and years
#
# Now we have all the codes for comtrade and CEPII at the 4 digit level. Now we need to join in order to do the comparisons

# %%
# Joinning the Comtrade databases
comtrade_dir = "comtrade_data_hs4"
files = sorted(glob.glob(os.path.join(comtrade_dir, "*.csv")))
print("Comtrade files found:", len(files))

keep_cols = [
    "flowCode", "reporterCode", "reporterISO",
    "partnerCode", "partnerISO",
    "cmdCode", "cmdDesc",
    "qtyUnitAbbr", "qty", "fobvalue"
]

def parse_year_from_filename(path):
    base = os.path.basename(path)
    m = re.search(r"(19\d{2}|20\d{2})", base)
    if not m:
        raise ValueError(f"No year found in filename: {base}")
    return int(m.group(0))

# HS4 codes you want to keep
hs4_keep = set(pd.Series(hs_four_code).astype(str).str.zfill(4))

dfs = []
for fp in files:
    df = pd.read_csv(fp)

    # ensure year exists (from file name)
    if "year" not in df.columns:
        df["year"] = parse_year_from_filename(fp)

    # ensure all expected columns exist
    for c in keep_cols:
        if c not in df.columns:
            df[c] = pd.NA

    df = df[keep_cols + ["year"]]
    dfs.append(df)

comtrade_db = pd.concat(dfs, ignore_index=True)
print("Final combined Comtrade DB shape:", comtrade_db.shape)

# Rename for alignment with CEPII
comtrade_db = comtrade_db.rename(columns={
    "reporterISO": "country_code",
    "partnerISO": "partner_code"
})

# Make sure cmdCode is a string and extract HS4
# (zfill to preserve leading zeros, then take first 4 chars)
comtrade_db["item4"] = (
    comtrade_db["cmdCode"]
      .astype(str)
      .str.replace(r"\.0$", "", regex=True)  # in case it got read as "0101.0"
      .str.strip()
      .str[:4]
)

# Keep only HS4 codes you care about
comtrade_db = comtrade_db[comtrade_db["item4"].isin(hs4_keep)].copy()

# Keep only relevant columns (HS4 version)
comtrade_db_clean = comtrade_db[[
    "flowCode", "country_code", "partner_code", "item4", "year", "fobvalue"
]].copy()

# Ensure fobvalue numeric (optional but recommended)
comtrade_db_clean["fobvalue"] = pd.to_numeric(comtrade_db_clean["fobvalue"], errors="coerce")

# Separate exports and imports
comtrade_db_X = comtrade_db_clean[comtrade_db_clean["flowCode"] == "X"].copy()
comtrade_db_M = comtrade_db_clean[comtrade_db_clean["flowCode"] == "M"].copy()

print("Exports shape:", comtrade_db_X.shape)
print("Imports shape:", comtrade_db_M.shape)
# Out:
# Comtrade files found: 184
# Final combined Comtrade DB shape: (3207718, 11)
# Exports shape: (1903808, 6)
# Imports shape: (1303910, 6)

# %%
comtrade_db_X.head()
# Out:
#       flowCode country_code partner_code item4  year  fobvalue
# 42283        X          ARG          AND  2005  2003     831.0
# 42284        X          ARG          BRB  2002  2003     945.0
# 42285        X          ARG          BRB  2005  2003    6272.0
# 42286        X          ARG          BIH  2002  2003    1400.0
# 42287        X          ARG          KHM  2005  2003    1515.0

# %% [markdown]
# # CEPII at 4 digits
#
# Now we get the CEPII database aggregated at 4 digits for the comparison with the Comtrade Database

# %%
# We use hs_four_code to only keep relevant 4-digit codes for this database

# Folder containing all the CSV files
data_path = Path('/Volumes/Toshi 1Tb/Trade/Trade Correo/')

# Ran the years 1996 to 2018 then it crashed, that's why in the output only years 2019-2023 will appear
# Years you want to process
years = range(1996, 2024)

# IMPORTANT: hs_four_code must exist already (list/Series/set of 4-digit strings)
# Example:
# hs_four_code = ["0101","0102","0201", ...]
hs4_keep = set(pd.Series(hs_four_code).astype(str))

key_cols = ["country_code", "partner_code", "item4"]

exports_panel = None
imports_panel = None

for year in years:
    print(f"Processing {year}...")

    # 1) Load
    file_path = data_path / f"tradeInGoods_baci_{year}.csv"
    db = pd.read_csv(file_path, sep=";", encoding="latin1", dtype=str, on_bad_lines="skip")

    # 2) Drop cols
    db_clean = db.drop(columns=["country_desciption", "partner_desciption", "item_description", "date"], errors="ignore")

    # 3) Fix decimal commas -> numeric
    for c in ["value", "item_code", "net_weight"]:
        if c in db_clean.columns:
            db_clean[c] = db_clean[c].astype(str).str.replace(",", ".", regex=False)
            db_clean[c] = pd.to_numeric(db_clean[c], errors="coerce")

    # 4) Build HS4 code from item_code
    db_clean["item4"] = db_clean["item_code"].astype(str).str[:4]

    # 5) Keep only your relevant HS4 codes
    db_clean = db_clean[db_clean["item4"].isin(hs4_keep)].copy()

    # 6) Split importer/exporter
    db_imp = db_clean[db_clean["flow"] == "I"].copy()
    db_exp = db_clean[db_clean["flow"] == "E"].copy()

    # 7) Group at HS4 level
    grouped_exp = db_exp.groupby(key_cols, as_index=False)["value"].sum()
    grouped_imp = db_imp.groupby(key_cols, as_index=False)["value"].sum()

    # 8) Rename value -> year column
    year_col = str(year)
    grouped_exp = grouped_exp.rename(columns={"value": year_col})
    grouped_imp = grouped_imp.rename(columns={"value": year_col})

    # 9) Full outer join into accumulating wide panels
    if exports_panel is None:
        exports_panel = grouped_exp
    else:
        exports_panel = exports_panel.merge(grouped_exp, on=key_cols, how="outer")

    if imports_panel is None:
        imports_panel = grouped_imp
    else:
        imports_panel = imports_panel.merge(grouped_imp, on=key_cols, how="outer")

# 10) Save
exports_panel.to_csv(data_path / "exports_CEPII_hs4.csv", index=False)
imports_panel.to_csv(data_path / "imports_CEPII_hs4.csv", index=False)

print("Done!")
# Out:
# Processing 1996...
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[6], line 25
#      23 # 1) Load
#      24 file_path = data_path / f"tradeInGoods_baci_{year}.csv"
# ---> 25 db = pd.read_csv(file_path, sep=";", encoding="latin1", dtype=str, on_bad_lines="skip")
#      27 # 2) Drop cols
#      28 db_clean = db.drop(columns=["country_desciption", "partner_desciption", "item_description", "date"], errors="ignore")
#
# ...

# %% [markdown]
# ### Joining CEPII and ComTrade

# %%
coco = pd.read_csv('/Volumes/Toshi 1Tb/Trade/Trade Correo/exports_CEPII_hs4.csv')
coco.head()
# Out:
#   country_code partner_code  item4  1996  1997  1998  1999  2000  2001  2002  \
# 0          ABW          AFG   2009   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1          ABW          AFG   2704   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          ABW          AFG   8414   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          ABW          AFG   8517   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4          ABW          AFG   9018   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#    ...  2014  2015  2016     2017      2018      2019  2020  2021  2022  2023
# 0  ...   NaN   NaN   NaN      NaN   15463.0     356.0   NaN   NaN   NaN   NaN
# 1  ...   NaN   NaN   NaN    338.0       NaN       NaN   NaN   NaN   NaN   NaN
# 2  ...   NaN   NaN   NaN      NaN       NaN     114.0   NaN   NaN   NaN   NaN
# 3  ...   NaN   NaN   NaN      NaN       NaN    3341.0   NaN   NaN   NaN   NaN
# 4  ...   NaN   NaN   NaN  12139.0  658282.0  153131.0   NaN   NaN   NaN   NaN
#
# [5 rows x 31 columns]

# %%
# Insert the CEPII database
CEPII_X = pd.read_csv('/Volumes/Toshi 1Tb/Trade/Trade Correo/exports_CEPII_hs4.csv')
CEPII_M = pd.read_csv('/Volumes/Toshi 1Tb/Trade/Trade Correo/imports_CEPII_hs4.csv')

# Countries that we'll compare
iso3_list = [
    "ARG","BRA","SLV","FRA","DEU",
    "HND","ITA","JPN","MEX","NZL",
    "NGA","PHL","RUS","SAU","ESP",
    "SUR","TUR","USA","ZWE","CHN",
    "CAN","GBR","SGP"
]

# We filter to only leave the relevant countries
CEPII_X_filt = CEPII_X[CEPII_X["country_code"].isin(iso3_list)].copy()
CEPII_M_filt = CEPII_M[CEPII_M["country_code"].isin(iso3_list)].copy()

years = [2003, 2009, 2017, 2021]
year_cols = [str(y) for y in years]
# adjust keys to match your CEPII structure
key_cols = ["country_code", "partner_code", "item4"]

# Reduce CEPII databases to only relevant columns and years
CEPII_X_sub = CEPII_X_filt[key_cols + year_cols]
CEPII_M_sub = CEPII_M_filt[key_cols + year_cols]

CEPII_X_long = CEPII_X_sub.melt(
    id_vars=key_cols,
    value_vars=year_cols,
    var_name="year",
    value_name="cepii_value"
)

CEPII_M_long = CEPII_M_sub.melt(
    id_vars=key_cols,
    value_vars=year_cols,
    var_name="year",
    value_name="cepii_value"
)

# make year numeric + value numeric
CEPII_X_long["year"] = CEPII_X_long["year"].astype(int)
CEPII_M_long["year"] = CEPII_M_long["year"].astype(int)

CEPII_X_long["cepii_value"] = pd.to_numeric(CEPII_X_long["cepii_value"], errors="coerce")
CEPII_M_long["cepii_value"] = pd.to_numeric(CEPII_M_long["cepii_value"], errors="coerce")

print(CEPII_X_long.head())
print(CEPII_M_long.head())
# Out:
#   country_code partner_code  item4  year  cepii_value
# 0          ARG          ABW   1001  2003          NaN
# 1          ARG          ABW   2008  2003          NaN
# 2          ARG          ABW   2009  2003          NaN
# 3          ARG          ABW   2516  2003          NaN
# 4          ARG          ABW   3902  2003          NaN
#   country_code partner_code  item4  year  cepii_value
# 0          ARG          ABW   2503  2003          NaN
# 1          ARG          ABW   2710  2003   13817092.0
# 2          ARG          ABW   2713  2003          NaN
# 3          ARG          ABW   3004  2003          NaN
# 4          ARG          ABW   3902  2003          NaN

# %% [markdown]
# ## Joined CEPII and ComTrade at the HS4 Level

# %%
#Prepare comtrade databases for the join

for df in [comtrade_db_X, comtrade_db_M, CEPII_X_long, CEPII_M_long]:
    df["country_code"] = df["country_code"].astype(str).str.strip().str.upper()
    df["partner_code"] = df["partner_code"].astype(str).str.strip().str.upper()
    df["item4"] = df["item4"].astype(str).str.zfill(4)
    df["year"] = df["year"].astype(int)

comtrade_X_agg = (
    comtrade_db_X
    .groupby(["country_code", "partner_code", "item4", "year"], as_index=False)
    .agg(comtrade_value=("fobvalue", "sum"))
)

comtrade_M_agg = (
    comtrade_db_M
    .groupby(["country_code", "partner_code", "item4", "year"], as_index=False)
    .agg(comtrade_value=("fobvalue", "sum"))
)

CEPII_X_joined = CEPII_X_long.merge(
    comtrade_X_agg,
    on=["country_code", "partner_code", "item4", "year"],
    how="left"
)

CEPII_M_joined = CEPII_M_long.merge(
    comtrade_M_agg,
    on=["country_code", "partner_code", "item4", "year"],
    how="left"
)

# %%
print("Exports — rows:", CEPII_X_joined.shape)
print("Imports — rows:", CEPII_M_joined.shape)

print("Share missing Comtrade (X):",
      CEPII_X_joined["comtrade_value"].isna().mean())

print("Share missing Comtrade (M):",
      CEPII_M_joined["comtrade_value"].isna().mean())

CEPII_X_joined.head()
# Out:
# Exports — rows: (4489312, 6)
# Imports — rows: (3346368, 6)
# Share missing Comtrade (X): 0.5934036217576324
# Share missing Comtrade (M): 0.6377708608258267
#   country_code partner_code item4  year  cepii_value  comtrade_value
# 0          ARG          ABW  1001  2003          NaN             NaN
# 1          ARG          ABW  2008  2003          NaN             NaN
# 2          ARG          ABW  2009  2003          NaN             NaN
# 3          ARG          ABW  2516  2003          NaN             NaN
# 4          ARG          ABW  3902  2003          NaN             NaN

# %% [markdown]
# ### NaN and Missing comparisons

# %%
# First, compare how many rows have one or the other missing
only_cepii_X_nan = (
    CEPII_X_joined["cepii_value"].isna() &
    CEPII_X_joined["comtrade_value"].notna()
).sum()

only_comtrade_X_nan = (
    CEPII_X_joined["cepii_value"].notna() &
    CEPII_X_joined["comtrade_value"].isna()
).sum()

# Exports: Comtrade has a lot of missing values compared to CEPII
print("Exports")
print(" NaN in CEPII:", only_cepii_X_nan, "| NaN in Comtrade:", only_comtrade_X_nan)

only_cepii_M_nan = (
    CEPII_M_joined["cepii_value"].isna() &
    CEPII_M_joined["comtrade_value"].notna()
).sum()

only_comtrade_M_nan = (
    CEPII_M_joined["cepii_value"].notna() &
    CEPII_M_joined["comtrade_value"].isna()
).sum()

# Imports: Comtrade has a lot of missing values compared to CEPII
print("Imports")
print(" NaN in CEPII:", only_cepii_M_nan, "| NaN in Comtrade:", only_comtrade_M_nan)

# --------------------------------------

# Now the comparisons
df_X_cmp = CEPII_X_joined[
    CEPII_X_joined["cepii_value"].notna() &
    CEPII_X_joined["comtrade_value"].notna()
].copy()

df_M_cmp = CEPII_M_joined[
    CEPII_M_joined["cepii_value"].notna() &
    CEPII_M_joined["comtrade_value"].notna()
].copy()

# Checking number of rows where both are NA

n_both_na_X = (
    CEPII_X_joined["cepii_value"].isna() &
    CEPII_X_joined["comtrade_value"].isna()
).sum()

print("Exports — rows where BOTH values are NA:", n_both_na_X)

n_both_na_M = (
    CEPII_M_joined["cepii_value"].isna() &
    CEPII_M_joined["comtrade_value"].isna()
).sum()

print("Imports — rows where BOTH values are NA:", n_both_na_M)
# Out:
# Exports
#  NaN in CEPII: 4343 | NaN in Comtrade: 610473
# Imports
#  NaN in CEPII: 6166 | NaN in Comtrade: 298892
# Exports — rows where BOTH values are NA: 2053501
# Imports — rows where BOTH values are NA: 1835324

# %% [markdown]
# ### NA Diagnostics

# %%
def na_diagnostics(df, name=""):
    both_na = (df["cepii_value"].isna() & df["comtrade_value"].isna()).sum()
    only_cepii_na = (df["cepii_value"].isna() & df["comtrade_value"].notna()).sum()
    only_comtrade_na = (df["cepii_value"].notna() & df["comtrade_value"].isna()).sum()
    neither_na = (df["cepii_value"].notna() & df["comtrade_value"].notna()).sum()

    out = pd.DataFrame({
        "case": [
            "both NA",
            "CEPII NA only",
            "Comtrade NA only",
            "neither NA"
        ],
        "n_obs": [
            both_na,
            only_cepii_na,
            only_comtrade_na,
            neither_na
        ]
    })

    print(f"\nNA diagnostics — {name}")
    print(out)
    return out

na_X = na_diagnostics(CEPII_X_joined, "Exports")
na_M = na_diagnostics(CEPII_M_joined, "Imports")
# Out:
# NA diagnostics — Exports
#                case    n_obs
# 0           both NA  2053501
# 1     CEPII NA only     4343
# 2  Comtrade NA only   610473
# 3        neither NA  1820995
#
# NA diagnostics — Imports
#                case    n_obs
# 0           both NA  1835324
# 1     CEPII NA only     6166
# 2  Comtrade NA only   298892
# 3        neither NA  1205986

# %% [markdown]
# ### Absolute and Relative gaps between CEPII & ComTrade

# %%
# Ensure numeric
df = CEPII_X_joined.copy()
df["cepii_value"] = pd.to_numeric(df["cepii_value"], errors="coerce")
df["comtrade_value"] = pd.to_numeric(df["comtrade_value"], errors="coerce")

# Aggregate by 2-digit code
sector_cmp = (
    df.groupby("item4", as_index=False)
      .agg(
          cepii_total=("cepii_value", "sum"),
          comtrade_total=("comtrade_value", "sum"),
          n_obs=("cepii_value", "size")
      )
)

# Gaps
sector_cmp["abs_gap"] = sector_cmp["cepii_total"] - sector_cmp["comtrade_total"]
sector_cmp["rel_gap"] = sector_cmp["abs_gap"] / sector_cmp["cepii_total"]

# Sort by largest absolute gap
sector_cmp = sector_cmp.sort_values("rel_gap", ascending=False)

sector_cmp.head(10)
# Out:
#     item4   cepii_total  comtrade_total  n_obs       abs_gap   rel_gap
# 394  9010  7.984519e+10    5.584134e+09  11032  7.426106e+10  0.930063
# 426  9109  1.811367e+09    2.061268e+08  12216  1.605241e+09  0.886204
# 52   2705  2.953737e+07    4.371644e+06   3296  2.516572e+07  0.851996
# 346  8525  8.373672e+11    1.400300e+11  16148  6.973372e+11  0.832773
# 396  9012  2.149038e+10    3.970324e+09  12308  1.752006e+10  0.815251
# 395  9011  3.404275e+10    6.567170e+09  13232  2.747558e+10  0.807091
# 227  8101  9.019830e+09    1.944678e+09   8932  7.075152e+09  0.784400
# 234  8109  4.282080e+09    9.404465e+08   9340  3.341633e+09  0.780376
# 193  7020  2.580490e+10    5.748503e+09  12900  2.005640e+10  0.777232
# 322  8485  1.572186e+10    3.509124e+09  13760  1.221274e+10  0.776800

# %%
sector_zeros = (
    df.groupby("item4")
      .agg(
          n_obs=("comtrade_value", "size"),
          n_positive=("comtrade_value", lambda x: (x > 0).sum()),
          n_zero=("comtrade_value", lambda x: (x == 0).sum()),
          n_nan=("comtrade_value", lambda x: x.isna().sum())
      )
      .reset_index()
)

# Shares
sector_zeros["share_zero"] = sector_zeros["n_zero"] / sector_zeros["n_obs"]
sector_zeros["share_nan"] = sector_zeros["n_nan"] / sector_zeros["n_obs"]
sector_zeros["share_positive"] = sector_zeros["n_positive"] / sector_zeros["n_obs"]

# Sort by zero share
sector_zeros = sector_zeros.sort_values("share_zero", ascending=False)

sector_zeros.head(10)
# Out:
#     item4  n_obs  n_positive  n_zero  n_nan  share_zero  share_nan  \
# 23   2505   9992        3268       2   6722    0.000200   0.672738
# 39   2521   5224         713       1   4510    0.000191   0.863323
# 375  8706   8108        2097       1   6010    0.000123   0.741243
# 202  7209   9396        3202       1   6193    0.000106   0.659110
# 47   2530   9508        3399       1   6108    0.000105   0.642406
# 41   2523  10600        3686       1   6913    0.000094   0.652170
# 265  8427  11384        5605       1   5778    0.000088   0.507554
# 436  9507  11408        4436       1   6971    0.000088   0.611062
# 279  8441  11432        5173       1   6258    0.000087   0.547411
# 300  8462  11868        5302       1   6565    0.000084   0.553168
#
#      share_positive
# 23         0.327062
# 39         0.136485
# 375        0.258633
# 202        0.340783
# 47         0.357488
# 41         0.347736
# 265        0.492358
# 436        0.388850
# 279        0.452502
# ...

# %% [markdown]
# # Graph Analysis

# %%
top_abs = (sector_cmp.sort_values("abs_gap", ascending=False).head(25))

top_rel = (sector_cmp.sort_values("rel_gap", ascending=False).head(25))

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

# --- Absolute gap (own ordering) ---
axes[0].bar(
    top_abs["item4"].astype(str),
    top_abs["abs_gap"]
)
axes[0].set_title("Largest Absolute CEPII–Comtrade Gaps by HS-4 Sector")
axes[0].set_xlabel("HS-4 Code")
axes[0].set_ylabel("Absolute Gap (USD)")
axes[0].tick_params(axis="x", rotation=45)

# --- Relative gap (own ordering) ---
axes[1].bar(
    top_rel["item4"].astype(str),
    top_rel["rel_gap"]
)
axes[1].set_title("Largest Relative CEPII–Comtrade Gaps by HS-4 Sector")
axes[1].set_xlabel("HS-4 Code")
axes[1].set_ylabel("Relative Gap")
axes[1].tick_params(axis="x", rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# Gaps are considerably higher in specific sectors compared to the HS2 level. Now we procede to disentangle this differences by year to see if this is attributable to one specific year.
#
# *Note*: 8525 refers to the following description: "Transmission apparatus for radio-broadcasting or television, whether or not incorporating reception apparatus or sound recording or reproducing apparatus; television cameras, digital cameras and video camera recorders."
#
# ## Per Year breakdown

# %%
def safe_filename(s: str) -> str:
    return "".join(c if c.isalnum() or c in "._-+" else "_" for c in str(s))

def make_year_only_gap_plots(
    df,
    year_col="year",
    item_col="item4",
    cepii_col="cepii_value",
    comtrade_col="comtrade_value",
    top_n=20,
    out_dir=None,          # e.g. "gap_plots_year_X_HS4"
    min_denom=1.0
):
    d = df.copy()

    # keep only rows where both exist
    d = d[d[cepii_col].notna() & d[comtrade_col].notna()].copy()

    # aggregate across ALL countries: year × HS2
    g = (d.groupby([year_col, item_col], as_index=False)
           .agg(cepii_value=(cepii_col, "sum"),
                comtrade_value=(comtrade_col, "sum")))

    # gaps
    g["abs_gap"] = (g["cepii_value"] - g["comtrade_value"]).abs()
    denom = g["comtrade_value"].abs().clip(lower=min_denom)
    g["rel_gap"] = g["abs_gap"] / denom

    if out_dir is not None:
        os.makedirs(out_dir, exist_ok=True)

    for year in sorted(g[year_col].dropna().unique()):
        sub = g[g[year_col] == year].copy()
        if sub.empty:
            continue

        top_abs = sub.nlargest(top_n, "abs_gap")
        top_rel = sub.nlargest(top_n, "rel_gap")

        fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(18, 6))

        # Absolute
        axes[0].bar(top_abs[item_col].astype(str), top_abs["abs_gap"])
        axes[0].set_title(f"{year} — Largest Absolute CEPII–Comtrade Gaps (HS4, all countries)")
        axes[0].set_xlabel("HS-4 Code")
        axes[0].set_ylabel("Absolute Gap (USD)")
        axes[0].tick_params(axis="x", rotation=45)

        # Relative
        axes[1].bar(top_rel[item_col].astype(str), top_rel["rel_gap"])
        axes[1].set_title(f"{year} — Largest Relative CEPII–Comtrade Gaps (HS4, all countries)")
        axes[1].set_xlabel("HS-4 Code")
        axes[1].set_ylabel("Relative Gap (abs_gap / comtrade)")
        axes[1].tick_params(axis="x", rotation=45)

        plt.tight_layout()

        if out_dir is None:
            plt.show()
        else:
            fn = f"gaps_ALLCOUNTRIES_{safe_filename(year)}.png"
            fig.savefig(os.path.join(out_dir, fn), dpi=200, bbox_inches="tight")
            plt.close(fig)

    return g

# %%
gaps_year_X = make_year_only_gap_plots(df_X_cmp, out_dir="gap_plots_year_X_HS4")
gaps_year_M = make_year_only_gap_plots(df_M_cmp, out_dir="gap_plots_year_M_HS4")

# %% [markdown]
# For years 2009, 2017, 2021, it appears that consistently code 8525 has the biggest absolute gap, with 8517 catching up to the same magnitude. In terms of relative differences, 9010 has for 2021 and 2017 the biggest, undisputed, highest relative difference,  with it becoming bigger over those two years. It appears that for years 2009 and 2003 the highest relative differences were small, only of 3% and 25%. However, for years 2017 the differences increases to over 50% and over 70% for 2021. 9109, although smaller, consistently ranks in the top 3 highest relative gaps for years 2009, 2017 and 2021. Now we proceed to analyze who are the main causes of the gaps for codes: 8525, 8517, 9010 and 9109.
#
# *Note*: Below are the meanings of each code:
# - 8525: Transmission apparatus for radio-broadcasting or television, whether or not incorporating reception apparatus or sound recording or reproducing apparatus; television cameras, digital cameras and video camera recorders
# - 8517: Telephone sets, including smartphones and other telephones for cellular/wireless networks; other apparatus for the transmission or reception of voice, images or other data (including wired/wireless networks), excluding items of 8443, 8525, 8527, or 8528
# - 9010: Photographic (including cinematographic) laboratory apparatus and equipment, n.e.c. in chapter 90; negatoscopes; projection screens
# - 9109: Clock movements; complete and assembled
#
# ## Code-specific country disaggregation

# %%
def country_gap_contributions(
    df,
    item_code,
    year=None,                # set to None to pool all years
    country_col="country_code",
    item_col="item4",
    cepii_col="cepii_value",
    comtrade_col="comtrade_value",
    min_denom=1.0
):
    d = df.copy()

    # Filter HS2
    d = d[d[item_col] == str(item_code)]

    # Optional year filter
    if year is not None:
        d = d[d["year"] == year]

    # Aggregate by country
    g = (
        d.groupby(country_col, as_index=False)
         .agg(
             cepii_value=(cepii_col, "sum"),
             comtrade_value=(comtrade_col, "sum")
         )
    )

    # Gaps
    g["abs_gap"] = g["cepii_value"] - g["comtrade_value"]
    g["abs_gap_abs"] = g["abs_gap"].abs()

    denom = g["comtrade_value"].abs().clip(lower=min_denom)
    g["rel_gap"] = g["abs_gap_abs"] / denom

    # Contribution shares
    total_gap = g["abs_gap_abs"].sum()
    g["share_of_gap"] = g["abs_gap_abs"] / total_gap

    return g.sort_values("abs_gap_abs", ascending=False)

def plot_country_contributions(
    g,
    item_code,
    top_n=15,
    title_suffix=""
):
    top = g.head(top_n)

    plt.figure(figsize=(10, 6))
    plt.barh(
        top["country_code"],
        top["share_of_gap"]
    )
    plt.gca().invert_yaxis()
    plt.xlabel("Share of total absolute gap")
    plt.title(f"Country contributions to HS2 = {item_code} gap {title_suffix}")
    plt.tight_layout()
    plt.show()

# %%
g_8525 = country_gap_contributions(df_X_cmp, item_code="8525")
plot_country_contributions(g_8525, item_code="8525")

g_8517 = country_gap_contributions(df_X_cmp, item_code="8517")
plot_country_contributions(g_8517, item_code="8517")

g_9010 = country_gap_contributions(df_X_cmp, item_code="9010")
plot_country_contributions(g_9010, item_code="9010")

g_9109 = country_gap_contributions(df_X_cmp, item_code="9109")
plot_country_contributions(g_9109, item_code="9109")

# %% [markdown]
# It seems that for the biggest absolute gaps, **China** consistently is the biggest contributor to this in the area of *telecommunications*. For camera related, Japan and USA seem to go head to head in the contribution to the Gaps. Finally, relating to clock movements, Germany is the biggest contributor to the Gap, although China follows once again.
# We proceed to see for all HS4 codes

# %%
def compute_country_year_total_gaps_hs4(
    df,
    country_col="country_code",
    year_col="year",
    item_col="item4",              # HS4 code
    cepii_col="cepii_value",
    comtrade_col="comtrade_value",
    min_denom=1.0
):
    d = df.copy()

    # (optional safety) ensure HS4 is string-like
    if item_col in d.columns:
        d[item_col] = d[item_col].astype(str)

    # Aggregate across ALL HS4 within (country, year)
    g = (
        d.groupby([country_col, year_col], as_index=False)
         .agg(
             cepii_value=(cepii_col, "sum"),
             comtrade_value=(comtrade_col, "sum")
         )
    )

    # Absolute gap
    g["abs_gap"] = (g["cepii_value"] - g["comtrade_value"]).abs()

    # Relative gap (stable)
    denom = g["comtrade_value"].abs().clip(lower=min_denom)
    g["rel_gap"] = g["abs_gap"] / denom

    return g

# %%
gaps_hs4_X = compute_country_year_total_gaps_hs4(df_X_cmp)  # exports
gaps_hs4_M = compute_country_year_total_gaps_hs4(df_M_cmp)  # imports

# %%
def plot_country_abs_gaps_year_hs4(
    gaps_country_year,
    year,
    top_n=15,
    country_col="country_code"
):
    sub = gaps_country_year[gaps_country_year["year"] == year].copy()
    sub = sub.sort_values("abs_gap", ascending=False).head(top_n)

    plt.figure(figsize=(10, 6))
    plt.barh(sub[country_col], sub["abs_gap"])
    plt.gca().invert_yaxis()
    plt.xlabel("Absolute gap (USD)")
    plt.title(f"Largest absolute mirror gaps by country ({year}) — all HS4")
    plt.tight_layout()
    plt.show()

# %%
for y in sorted(gaps_hs4_X["year"].unique()):
    plot_country_abs_gaps_year_hs4(gaps_hs4_X, year=y, top_n=15)

# %%
def plot_country_gap_shares_year_hs4(
    gaps_country_year,
    year,
    top_n=15,
    country_col="country_code"
):
    sub = gaps_country_year[gaps_country_year["year"] == year].copy()
    if sub.empty:
        print(f"No data for {year}")
        return

    total = sub["abs_gap"].sum()
    if total == 0 or pd.isna(total):
        print(f"Total gap is zero/NA for {year}")
        return

    sub["share_of_gap"] = sub["abs_gap"] / total
    sub = sub.sort_values("share_of_gap", ascending=False).head(top_n)

    plt.figure(figsize=(10, 6))
    plt.barh(sub[country_col], sub["share_of_gap"])
    plt.gca().invert_yaxis()
    plt.xlabel("Share of total absolute gap")
    plt.title(f"Country contributions to total mirror gap ({year}) — all HS4")
    plt.tight_layout()
    plt.show()

# %%
for y in sorted(gaps_hs4_X["year"].unique()):
    plot_country_gap_shares_year_hs4(gaps_hs4_X, year=y, top_n=15)

# %% [markdown]
# Once again, both in absolute and in relative terms, **China** has the largest absolute gap and relative contribution gap at the HS4 level overall.
